# %% [markdown]
# ## Prejudice Remover Regularizer for Images

# %% [markdown]
# 1. [Introduction](#1.-Introduction)
# 2. [Data preparation](#2.-Data-preparation)
# 3. [Classifier network](#3.-Classifier-network)
# 	*  [Model Fairness for Classifier Network](#Model-Fairness-for-Classifier)
# 4. [Prejudice Remover Regularizer](#4.-Prejudice-Remover-Regularizer)
# 	* [Model Fairness: with PRR](#Model-Fairness:-with-PRR)
# 5. [Summary](#5.-Summary)
# 6. [References](#References)

# %% [markdown]
# ### 1. Introduction
# Welcome !
#
# We hope you have had a chance to go through previous tutorials on fairness in AI by Sony. In one of the tutorials, we applied `Prejudice Remover Regularizer (hereafter referred to as PRR)` technique to train a fair classifier on UCI Adult (Census) Dataset. As a result, model fairness improved without causing much drop in accuracy.
#
# In this tutorial, we will explore PRR for visual recognition task on CelebA dataset (real world image dataset).
#
# Before we go into a detailed explanation of the PRR training procedure, here is a sneak peek into the steps involved in the process:

# %% [markdown]
# ### Preparation
# Let's start by installing nnabla and accessing [nnabla-examples repository](https://github.com/sony/nnabla-examples). If you're running on Google Colab, make sure that your Runtime setting is set as GPU, which can be set up from the top menu (Runtime → change runtime type), and make sure to click **Connect** on the top right-hand side of the screen before you start.

# %%
# Preparation
# !git clone https://github.com/sony/nnabla-examples.git
# %cd nnabla-examples/responsible_ai/prejudice_remover_regularizer_images
# !pip install nnabla-ext-cuda100
# !pip install albumentations

import cv2
from google.colab.patches import cv2_imshow
img = cv2.imread('images/Prejudice_Remover_Regularizer_workflow_diagram.png')
cv2_imshow(img)

# %% [markdown]
# As illustrated in the picture, in the first step we will train a classifier model to make predictions & analyze model fairness. Then the subsequent step shows how PRR training can be employed to make the model fair if the fairness metric is not satisfactory.
#
# At first, all we need is to import all the necessary python libraries.

# %%
import os
import glob
import pickle
import shutil
import numpy as np
from PIL import Image
import albumentations as A
import nnabla as nn
from nnabla.utils.data_iterator import data_iterator_simple
import classifier as clf
from utils import utils
# Out:
# 2022-06-30 20:32:54,064 [nnabla][INFO]: Initializing CPU extension...

# %% [markdown]
# Let us train an `Attractive` classifier that is not dependent on gender expression.

# %% [markdown]
# ### 2. Data preparation
#
# Before training a classifier model, let's download and split the CelebA dataset into three categories: training, validation and test sets.

# %%
# download the celeba dataset and unzip
URL = "https://www.dropbox.com/s/d1kjpkqklf0uw77/celeba.zip?dl=0"
ZIP_FILE= "./data/celeba.zip"
# !mkdir -p ./data/
# !wget -N $URL -O $ZIP_FILE
# !unzip $ZIP_FILE -d ./data/
# !rm $ZIP_FILE
# Out:
# WARNING: timestamping does nothing in combination with -O. See the manual
# for details.
#
# --2022-06-30 20:33:09--  https://www.dropbox.com/s/d1kjpkqklf0uw77/celeba.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.81.18, 2620:100:6031:18::a27d:5112
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.81.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/d1kjpkqklf0uw77/celeba.zip [following]
# --2022-06-30 20:33:10--  https://www.dropbox.com/s/raw/d1kjpkqklf0uw77/celeba.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uc4e30abf6335321d21556e2482a.dl.dropboxusercontent.com/cd/0/inline/BoPF7LKZHT-wSYIq-WjP183U9gtYSx-c8OOT_KvX0fOp0xilH0nUFdymgGgT_1U7D34BGd0MNsFJ0bq6MYp-kt0I-nUSaA-J8ozwwYEwRcOkOkaoTHPmRD5-_0OjEvLzluCXCK1v4ZA9Yj5Ba4yU9WXJuBPm3047HnjMnQIFyWuSPg/file# [following]
# --2022-06-30 20:33:10--  https://uc4e30abf6335321d21556e2482a.dl.dropboxusercontent.com/cd/0/inline/BoPF7LKZHT-wSYIq-WjP183U9gtYSx-c8OOT_KvX0fOp0xilH0nUFdymgGgT_1U7D34BGd0MNsFJ0bq6MYp-kt0I-nUSaA-J8ozwwYEwRcOkOkaoTHPmRD5-_0OjEvLzluCXCK1v4ZA9Yj5Ba4yU9WXJuBPm3047HnjMnQIFyWuSPg/file
# Resolving uc4e30abf6335321d21556e2482a.dl.dropboxusercontent.com (uc4e30abf6335321d21556e2482a.dl.dropboxusercontent.com)... 162.125.81.15, 2620:100:6031:15::a27d:510f
# Connecting to uc4e30abf6335321d21556e2482a.dl.dropboxusercontent.com (uc4e30abf6335321d21556e2482a.dl.dropboxusercontent.com)|162.125.81.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BoNe9qShmn-qLg0SVpaa903olPb5ksUmWvJCoPUpFstuS4VV3WFhfuVaysml2UhpsDUir25hJeQbhwtSgm7T7yXVqZolNZ-fc3ILFg171uwg74FVcT25gsHTjF3EGncDZxnUNw8it8WlDSBimx4aI9uQy2zmZseTdzMVwCB81jwHnymcQ-T4P_zoXrKAxfERdiElUpq12gWBmbcnnKUdRKy6GdpJSEM7NEvd-lrGevqdLyuINJa7NHcQiZy8_LvKBCxhh1jEKE8SO9kOYd7lOjbgCGxvywqxrnLImPVJkZ97ULtghDFr60q-YPlHLVwR0eHsFtW2N2VD7yIaGM9jHT84RFP67m_5Dhfd-wQQDNDpPY8oRTxmq1dQGwFVb0h47LPiqc6-rijNrxp_aDtBl9Ls5pjIUOUavR2q5siNVQeIqQ/file [following]
# --2022-06-30 20:33:11--  https://uc4e30abf6335321d21556e2482a.dl.dropboxusercontent.com/cd/0/inline2/BoNe9qShmn-qLg0SVpaa903olPb5ksUmWvJCoPUpFstuS4VV3WFhfuVaysml2UhpsDUir25hJeQbhwtSgm7T7yXVqZolNZ-fc3ILFg171uwg74FVcT25gsHTjF3EGncDZxnUNw8it8WlDSBimx4aI9uQy2zmZseTdzMVwCB81jwHnymcQ-T4P_zoXrKAxfERdiElUpq12gWBmbcnnKUdRKy6GdpJSEM7NEvd-lrGevqdLyuINJa7NHcQiZy8_LvKBCxhh1jEKE8SO9kOYd7lOjbgCGxvywqxrnLImPVJkZ97ULtghDFr60q-YPlHLVwR0eHsFtW2N2VD7yIaGM9jHT84RFP67m_5Dhfd-wQQDNDpPY8oRTxmq1dQGwFVb0h47LPiqc6-rijNrxp_aDtBl9Ls5pjIUOUavR2q5siNVQeIqQ/file
# Reusing existing connection to uc4e30abf6335321d21556e2482a.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1417753833 (1.3G) [application/zip]
# Saving to: ‘./data/celeba.zip’
#
# ./data/celeba.zip   100%[===================>]   1.32G  6.77MB/s    in 2m 57s
#
# 2022-06-30 20:36:09 (7.62 MB/s) - ‘./data/celeba.zip’ saved [1417753833/1417753833]
#
# Archive:  ./data/celeba.zip
#    creating: ./data/celeba/
#    creating: ./data/celeba/images/
#   inflating: ./data/celeba/images/189602.jpg
#   inflating: ./data/celeba/images/003786.jpg
#   inflating: ./data/celeba/images/174094.jpg
#   inflating: ./data/celeba/images/143993.jpg
#   inflating: ./data/celeba/images/146533.jpg
#   inflating: ./data/celeba/images/053154.jpg
#   inflating: ./data/celeba/images/155705.jpg
#   inflating: ./data/celeba/images/105765.jpg
#   inflating: ./data/celeba/images/042313.jpg
#   inflating: ./data/celeba/images/115415.jpg
#   inflating: ./data/celeba/images/029614.jpg
#   inflating: ./data/celeba/images/115740.jpg
#   inflating: ./data/celeba/images/139246.jpg
#   inflating: ./data/celeba/images/025939.jpg
#   inflating: ./data/celeba/images/172851.jpg
#   inflating: ./data/celeba/images/152104.jpg
#   inflating: ./data/celeba/images/056425.jpg
#   inflating: ./data/celeba/images/004263.jpg
#   inflating: ./data/celeba/images/070187.jpg
#   inflating: ./data/celeba/images/098742.jpg
#   inflating: ./data/celeba/images/050239.jpg
#   inflating: ./data/celeba/images/095387.jpg
#   inflating: ./data/celeba/images/092662.jpg
#   inflating: ./data/celeba/images/118118.jpg
#   inflating: ./data/celeba/images/121433.jpg
#   inflating: ./data/celeba/images/049314.jpg
#   inflating: ./data/celeba/images/149740.jpg
#   inflating: ./data/celeba/images/135996.jpg
#   inflating: ./data/celeba/images/117434.jpg
#   inflating: ./data/celeba/images/090085.jpg
#   inflating: ./data/celeba/images/088740.jpg
#   inflating: ./data/celeba/images/032745.jpg
#   inflating: ./data/celeba/images/122783.jpg
#   inflating: ./data/celeba/images/156382.jpg
#   inflating: ./data/celeba/images/199911.jpg
#   inflating: ./data/celeba/images/099461.jpg
#   inflating: ./data/celeba/images/015298.jpg
#   inflating: ./data/celeba/images/028683.jpg
#   inflating: ./data/celeba/images/013926.jpg
#   inflating: ./data/celeba/images/066219.jpg
#   inflating: ./data/celeba/images/038032.jpg
#   inflating: ./data/celeba/images/099530.jpg
#   inflating: ./data/celeba/images/090698.jpg
#   inflating: ./data/celeba/images/063384.jpg
#   inflating: ./data/celeba/images/168235.jpg
#   inflating: ./data/celeba/images/082239.jpg
#   inflating: ./data/celeba/images/072029.jpg
#   inflating: ./data/celeba/images/040606.jpg
#   inflating: ./data/celeba/images/008480.jpg
#   inflating: ./data/celeba/images/164980.jpg
#   inflating: ./data/celeba/images/180744.jpg
#   inflating: ./data/celeba/images/019600.jpg
#   inflating: ./data/celeba/images/121441.jpg
#   inflating: ./data/celeba/images/062115.jpg
#   inflating: ./data/celeba/images/005666.jpg
#   inflating: ./data/celeba/images/101908.jpg
#   inflating: ./data/celeba/images/135803.jpg
#   inflating: ./data/celeba/images/103364.jpg
#   inflating: ./data/celeba/images/017478.jpg
#   inflating: ./data/celeba/images/149988.jpg
#   inflating: ./data/celeba/images/026455.jpg
#   inflating: ./data/celeba/images/087346.jpg
#   inflating: ./data/celeba/images/152121.jpg
#   inflating: ./data/celeba/images/091931.jpg
#   inflating: ./data/celeba/images/178863.jpg
#   inflating: ./data/celeba/images/031767.jpg
#   inflating: ./data/celeba/images/042551.jpg
#   inflating: ./data/celeba/images/100321.jpg
#   inflating: ./data/celeba/images/088013.jpg
#   inflating: ./data/celeba/images/153882.jpg
#   inflating: ./data/celeba/images/008034.jpg
#   inflating: ./data/celeba/images/171430.jpg
#   inflating: ./data/celeba/images/124054.jpg
#   inflating: ./data/celeba/images/033490.jpg
#   inflating: ./data/celeba/images/003354.jpg
#   inflating: ./data/celeba/images/039999.jpg
#   inflating: ./data/celeba/images/199178.jpg
#   inflating: ./data/celeba/images/140880.jpg
#   inflating: ./data/celeba/images/093545.jpg
#   inflating: ./data/celeba/images/078172.jpg
#   inflating: ./data/celeba/images/010161.jpg
#   inflating: ./data/celeba/images/197707.jpg
#   inflating: ./data/celeba/images/086967.jpg
#   inflating: ./data/celeba/images/035756.jpg
#   inflating: ./data/celeba/images/060645.jpg
#   inflating: ./data/celeba/images/091964.jpg
#   inflating: ./data/celeba/images/163605.jpg
#   inflating: ./data/celeba/images/036894.jpg
#   inflating: ./data/celeba/images/043832.jpg
#   inflating: ./data/celeba/images/086485.jpg
#   inflating: ./data/celeba/images/047049.jpg
#   inflating: ./data/celeba/images/079482.jpg
#   inflating: ./data/celeba/images/118984.jpg
#   inflating: ./data/celeba/images/113178.jpg
#   inflating: ./data/celeba/images/103555.jpg
#   inflating: ./data/celeba/images/013023.jpg
#   inflating: ./data/celeba/images/037646.jpg
#   inflating: ./data/celeba/images/184736.jpg
#   inflating: ./data/celeba/images/078958.jpg
#   inflating: ./data/celeba/images/174325.jpg
#   inflating: ./data/celeba/images/123774.jpg
#   inflating: ./data/celeba/images/147410.jpg
#   inflating: ./data/celeba/images/154972.jpg
#   inflating: ./data/celeba/images/191448.jpg
#   inflating: ./data/celeba/images/117522.jpg
#   inflating: ./data/celeba/images/064231.jpg
#   inflating: ./data/celeba/images/155162.jpg
#   inflating: ./data/celeba/images/014968.jpg
#   inflating: ./data/celeba/images/114654.jpg
#   inflating: ./data/celeba/images/195108.jpg
#   inflating: ./data/celeba/images/067259.jpg
#   inflating: ./data/celeba/images/185995.jpg
#   inflating: ./data/celeba/images/194438.jpg
#   inflating: ./data/celeba/images/094253.jpg
#   inflating: ./data/celeba/images/053779.jpg
#   inflating: ./data/celeba/images/095008.jpg
#   inflating: ./data/celeba/images/058405.jpg
#   inflating: ./data/celeba/images/166022.jpg
#   inflating: ./data/celeba/images/146353.jpg
#   inflating: ./data/celeba/images/068395.jpg
#   inflating: ./data/celeba/images/194336.jpg
#   inflating: ./data/celeba/images/063956.jpg
#   inflating: ./data/celeba/images/044007.jpg
#   inflating: ./data/celeba/images/045808.jpg
#   inflating: ./data/celeba/images/074299.jpg
#   inflating: ./data/celeba/images/092731.jpg
#   inflating: ./data/celeba/images/110136.jpg
#   inflating: ./data/celeba/images/003032.jpg
#   inflating: ./data/celeba/images/004944.jpg
#   inflating: ./data/celeba/images/174494.jpg
#   inflating: ./data/celeba/images/105139.jpg
#   inflating: ./data/celeba/images/038030.jpg
#   inflating: ./data/celeba/images/056374.jpg
#   inflating: ./data/celeba/images/202548.jpg
#   inflating: ./data/celeba/images/046612.jpg
#   inflating: ./data/celeba/images/025336.jpg
#   inflating: ./data/celeba/images/028838.jpg
#   inflating: ./data/celeba/images/062906.jpg
#   inflating: ./data/celeba/images/107092.jpg
#   inflating: ./data/celeba/images/075101.jpg
#   inflating: ./data/celeba/images/082014.jpg
#   inflating: ./data/celeba/images/082398.jpg
#   inflating: ./data/celeba/images/196112.jpg
#   inflating: ./data/celeba/images/183634.jpg
#   inflating: ./data/celeba/images/023904.jpg
#   inflating: ./data/celeba/images/011119.jpg
#   inflating: ./data/celeba/images/165043.jpg
#   inflating: ./data/celeba/images/157617.jpg
#   inflating: ./data/celeba/images/175938.jpg
#   inflating: ./data/celeba/images/021945.jpg
#   inflating: ./data/celeba/images/117705.jpg
#   inflating: ./data/celeba/images/003468.jpg
#   inflating: ./data/celeba/images/117882.jpg
#   inflating: ./data/celeba/images/168842.jpg
#   inflating: ./data/celeba/images/055951.jpg
#   inflating: ./data/celeba/images/114394.jpg
#   inflating: ./data/celeba/images/127399.jpg
#   inflating: ./data/celeba/images/061682.jpg
#   inflating: ./data/celeba/images/187656.jpg
#   inflating: ./data/celeba/images/081241.jpg
#   inflating: ./data/celeba/images/009126.jpg
#   inflating: ./data/celeba/images/028896.jpg
#   inflating: ./data/celeba/images/163761.jpg
#   inflating: ./data/celeba/images/012100.jpg
#   inflating: ./data/celeba/images/196426.jpg
#   inflating: ./data/celeba/images/011975.jpg
#   inflating: ./data/celeba/images/162059.jpg
#   inflating: ./data/celeba/images/134862.jpg
#   inflating: ./data/celeba/images/104700.jpg
#   inflating: ./data/celeba/images/086952.jpg
#   inflating: ./data/celeba/images/096560.jpg
#   inflating: ./data/celeba/images/174415.jpg
#   inflating: ./data/celeba/images/177425.jpg
#   inflating: ./data/celeba/images/010481.jpg
#   inflating: ./data/celeba/images/150167.jpg
#   inflating: ./data/celeba/images/152534.jpg
#   inflating: ./data/celeba/images/082041.jpg
#   inflating: ./data/celeba/images/193823.jpg
#   inflating: ./data/celeba/images/176522.jpg
#   inflating: ./data/celeba/images/078441.jpg
#   inflating: ./data/celeba/images/070760.jpg
#   inflating: ./data/celeba/images/002350.jpg
#   inflating: ./data/celeba/images/119608.jpg
#   inflating: ./data/celeba/images/066386.jpg
#   inflating: ./data/celeba/images/025761.jpg
#   inflating: ./data/celeba/images/149436.jpg
#   inflating: ./data/celeba/images/131273.jpg
#   inflating: ./data/celeba/images/196045.jpg
#   inflating: ./data/celeba/images/091925.jpg
#   inflating: ./data/celeba/images/152756.jpg
#   inflating: ./data/celeba/images/101182.jpg
#   inflating: ./data/celeba/images/027584.jpg
#   inflating: ./data/celeba/images/085442.jpg
#   inflating: ./data/celeba/images/049795.jpg
#   inflating: ./data/celeba/images/152226.jpg
#   inflating: ./data/celeba/images/117872.jpg
#   inflating: ./data/celeba/images/198666.jpg
#   inflating: ./data/celeba/images/108767.jpg
#   inflating: ./data/celeba/images/084671.jpg
#   inflating: ./data/celeba/images/026826.jpg
#   inflating: ./data/celeba/images/177513.jpg
#   inflating: ./data/celeba/images/116717.jpg
#   inflating: ./data/celeba/images/182943.jpg
#   inflating: ./data/celeba/images/022167.jpg
#   inflating: ./data/celeba/images/070571.jpg
#   inflating: ./data/celeba/images/102290.jpg
#   inflating: ./data/celeba/images/103031.jpg
#   inflating: ./data/celeba/images/045643.jpg
#   inflating: ./data/celeba/images/084116.jpg
#   inflating: ./data/celeba/images/142958.jpg
#   inflating: ./data/celeba/images/166082.jpg
#   inflating: ./data/celeba/images/186146.jpg
#   inflating: ./data/celeba/images/169139.jpg
#   inflating: ./data/celeba/images/112609.jpg
#   inflating: ./data/celeba/images/092525.jpg
#   inflating: ./data/celeba/images/021034.jpg
#   inflating: ./data/celeba/images/044737.jpg
#   inflating: ./data/celeba/images/196882.jpg
#   inflating: ./data/celeba/images/097912.jpg
#   inflating: ./data/celeba/images/192137.jpg
#   inflating: ./data/celeba/images/016747.jpg
#   inflating: ./data/celeba/images/073426.jpg
#   inflating: ./data/celeba/images/176828.jpg
#   inflating: ./data/celeba/images/169018.jpg
#   inflating: ./data/celeba/images/099817.jpg
#   inflating: ./data/celeba/images/082137.jpg
#   inflating: ./data/celeba/images/055315.jpg
#   inflating: ./data/celeba/images/133310.jpg
#   inflating: ./data/celeba/images/011006.jpg
#   inflating: ./data/celeba/images/029960.jpg
#   inflating: ./data/celeba/images/041854.jpg
#   inflating: ./data/celeba/images/087917.jpg
#   inflating: ./data/celeba/images/140659.jpg
#   inflating: ./data/celeba/images/036583.jpg
#   inflating: ./data/celeba/images/077680.jpg
#   inflating: ./data/celeba/images/168759.jpg
#   inflating: ./data/celeba/images/131683.jpg
#   inflating: ./data/celeba/images/135923.jpg
#   inflating: ./data/celeba/images/075302.jpg
#   inflating: ./data/celeba/images/130608.jpg
#   inflating: ./data/celeba/images/192586.jpg
#   inflating: ./data/celeba/images/170301.jpg
#   inflating: ./data/celeba/images/056275.jpg
#   inflating: ./data/celeba/images/064392.jpg
#   inflating: ./data/celeba/images/074784.jpg
#   inflating: ./data/celeba/images/109819.jpg
#   inflating: ./data/celeba/images/012748.jpg
#   inflating: ./data/celeba/images/035539.jpg
#   inflating: ./data/celeba/images/069104.jpg
#   inflating: ./data/celeba/images/114782.jpg
#   inflating: ./data/celeba/images/141253.jpg
#   inflating: ./data/celeba/images/106954.jpg
#   inflating: ./data/celeba/images/146024.jpg
#   inflating: ./data/celeba/images/001519.jpg
#   inflating: ./data/celeba/images/200817.jpg
#   inflating: ./data/celeba/images/048688.jpg
#   inflating: ./data/celeba/images/045275.jpg
#   inflating: ./data/celeba/images/150819.jpg
#   inflating: ./data/celeba/images/158525.jpg
#   inflating: ./data/celeba/images/151514.jpg
#   inflating: ./data/celeba/images/124501.jpg
#   inflating: ./data/celeba/images/072970.jpg
#   inflating: ./data/celeba/images/105581.jpg
#   inflating: ./data/celeba/images/037014.jpg
#   inflating: ./data/celeba/images/093101.jpg
#   inflating: ./data/celeba/images/129473.jpg
#   inflating: ./data/celeba/images/006793.jpg
#   inflating: ./data/celeba/images/056798.jpg
#   inflating: ./data/celeba/images/048064.jpg
#   inflating: ./data/celeba/images/185650.jpg
#   inflating: ./data/celeba/images/052632.jpg
#   inflating: ./data/celeba/images/054844.jpg
#   inflating: ./data/celeba/images/161543.jpg
#   inflating: ./data/celeba/images/123228.jpg
#   inflating: ./data/celeba/images/038930.jpg
#   inflating: ./data/celeba/images/053276.jpg
#   inflating: ./data/celeba/images/103007.jpg
#   inflating: ./data/celeba/images/014698.jpg
#   inflating: ./data/celeba/images/023255.jpg
#   inflating: ./data/celeba/images/079589.jpg
#   inflating: ./data/celeba/images/045464.jpg
#   inflating: ./data/celeba/images/022817.jpg
#   inflating: ./data/celeba/images/058591.jpg
#   inflating: ./data/celeba/images/116910.jpg
#   inflating: ./data/celeba/images/008371.jpg
#   inflating: ./data/celeba/images/170056.jpg
#   inflating: ./data/celeba/images/090146.jpg
#   inflating: ./data/celeba/images/034099.jpg
#   inflating: ./data/celeba/images/090404.jpg
#   inflating: ./data/celeba/images/061163.jpg
#   inflating: ./data/celeba/images/171693.jpg
#   inflating: ./data/celeba/images/065308.jpg
#   inflating: ./data/celeba/images/046668.jpg
#   inflating: ./data/celeba/images/066711.jpg
#   inflating: ./data/celeba/images/002615.jpg
#   inflating: ./data/celeba/images/135524.jpg
#   inflating: ./data/celeba/images/002318.jpg
#   inflating: ./data/celeba/images/047501.jpg
#   inflating: ./data/celeba/images/023989.jpg
#   inflating: ./data/celeba/images/105374.jpg
#   inflating: ./data/celeba/images/188911.jpg
#   inflating: ./data/celeba/images/190115.jpg
#   inflating: ./data/celeba/images/168098.jpg
#   inflating: ./data/celeba/images/104355.jpg
#   inflating: ./data/celeba/images/065726.jpg
#   inflating: ./data/celeba/images/011366.jpg
#   inflating: ./data/celeba/images/090562.jpg
#   inflating: ./data/celeba/images/172544.jpg
#   inflating: ./data/celeba/images/043638.jpg
#   inflating: ./data/celeba/images/174749.jpg
#   inflating: ./data/celeba/images/143637.jpg
#   inflating: ./data/celeba/images/088467.jpg
#   inflating: ./data/celeba/images/188017.jpg
#   inflating: ./data/celeba/images/096773.jpg
#   inflating: ./data/celeba/images/036079.jpg
#   inflating: ./data/celeba/images/112963.jpg
#   inflating: ./data/celeba/images/145386.jpg
#   inflating: ./data/celeba/images/098967.jpg
#   inflating: ./data/celeba/images/153162.jpg
#   inflating: ./data/celeba/images/119787.jpg
#   inflating: ./data/celeba/images/149927.jpg
#   inflating: ./data/celeba/images/095350.jpg
#   inflating: ./data/celeba/images/154550.jpg
#   inflating: ./data/celeba/images/107748.jpg
#   inflating: ./data/celeba/images/004331.jpg
#   inflating: ./data/celeba/images/180876.jpg
#   inflating: ./data/celeba/images/111436.jpg
#   inflating: ./data/celeba/images/001274.jpg
#   inflating: ./data/celeba/images/039148.jpg
#   inflating: ./data/celeba/images/153703.jpg
#   inflating: ./data/celeba/images/148552.jpg
#   inflating: ./data/celeba/images/047092.jpg
#   inflating: ./data/celeba/images/081840.jpg
#   inflating: ./data/celeba/images/023329.jpg
#   inflating: ./data/celeba/images/134084.jpg
#   inflating: ./data/celeba/images/027006.jpg
#   inflating: ./data/celeba/images/097761.jpg
#   inflating: ./data/celeba/images/123863.jpg
#   inflating: ./data/celeba/images/037868.jpg
#   inflating: ./data/celeba/images/089856.jpg
#   inflating: ./data/celeba/images/119220.jpg
#   inflating: ./data/celeba/images/168458.jpg
#   inflating: ./data/celeba/images/151646.jpg
#   inflating: ./data/celeba/images/087602.jpg
#   inflating: ./data/celeba/images/089623.jpg
#   inflating: ./data/celeba/images/053737.jpg
#   inflating: ./data/celeba/images/154217.jpg
#   inflating: ./data/celeba/images/093178.jpg
#   inflating: ./data/celeba/images/187525.jpg
#   inflating: ./data/celeba/images/043841.jpg
#   inflating: ./data/celeba/images/168454.jpg
#   inflating: ./data/celeba/images/039444.jpg
#   inflating: ./data/celeba/images/182247.jpg
#   inflating: ./data/celeba/images/142099.jpg
#   inflating: ./data/celeba/images/018560.jpg
#   inflating: ./data/celeba/images/174409.jpg
#   inflating: ./data/celeba/images/202594.jpg
#   inflating: ./data/celeba/images/056031.jpg
#   inflating: ./data/celeba/images/166449.jpg
#   inflating: ./data/celeba/images/106237.jpg
#   inflating: ./data/celeba/images/005695.jpg
#   inflating: ./data/celeba/images/181395.jpg
#   inflating: ./data/celeba/images/135006.jpg
#   inflating: ./data/celeba/images/188446.jpg
#   inflating: ./data/celeba/images/013036.jpg
#   inflating: ./data/celeba/images/132864.jpg
#   inflating: ./data/celeba/images/081127.jpg
#   inflating: ./data/celeba/images/017452.jpg
#   inflating: ./data/celeba/images/014421.jpg
#   inflating: ./data/celeba/images/090554.jpg
#   inflating: ./data/celeba/images/126711.jpg
#   inflating: ./data/celeba/images/191898.jpg
#   inflating: ./data/celeba/images/149864.jpg
#   inflating: ./data/celeba/images/090598.jpg
#   inflating: ./data/celeba/images/006449.jpg
#   inflating: ./data/celeba/images/008603.jpg
#   inflating: ./data/celeba/images/122016.jpg
#   inflating: ./data/celeba/images/150093.jpg
#   inflating: ./data/celeba/images/148080.jpg
#   inflating: ./data/celeba/images/051947.jpg
#   inflating: ./data/celeba/images/147349.jpg
#   inflating: ./data/celeba/images/149464.jpg
#   inflating: ./data/celeba/images/123042.jpg
#   inflating: ./data/celeba/images/177846.jpg
#   inflating: ./data/celeba/images/030754.jpg
#   inflating: ./data/celeba/images/157045.jpg
#   inflating: ./data/celeba/images/150834.jpg
#   inflating: ./data/celeba/images/072651.jpg
#   inflating: ./data/celeba/images/074542.jpg
#   inflating: ./data/celeba/images/191681.jpg
#   inflating: ./data/celeba/images/047574.jpg
#   inflating: ./data/celeba/images/047457.jpg
#   inflating: ./data/celeba/images/034985.jpg
#   inflating: ./data/celeba/images/065331.jpg
#   inflating: ./data/celeba/images/007920.jpg
#   inflating: ./data/celeba/images/062469.jpg
#   inflating: ./data/celeba/images/141317.jpg
#   inflating: ./data/celeba/images/170217.jpg
#   inflating: ./data/celeba/images/022361.jpg
#   inflating: ./data/celeba/images/003625.jpg
#   inflating: ./data/celeba/images/170166.jpg
#   inflating: ./data/celeba/images/058993.jpg
#   inflating: ./data/celeba/images/149895.jpg
#   inflating: ./data/celeba/images/202230.jpg
#   inflating: ./data/celeba/images/142378.jpg
#   inflating: ./data/celeba/images/064919.jpg
#   inflating: ./data/celeba/images/107406.jpg
#   inflating: ./data/celeba/images/161859.jpg
#   inflating: ./data/celeba/images/021969.jpg
#   inflating: ./data/celeba/images/074089.jpg
#   inflating: ./data/celeba/images/105578.jpg
#   inflating: ./data/celeba/images/069240.jpg
#   inflating: ./data/celeba/images/051489.jpg
#   inflating: ./data/celeba/images/050737.jpg
#   inflating: ./data/celeba/images/125258.jpg
#   inflating: ./data/celeba/images/060784.jpg
#   inflating: ./data/celeba/images/056520.jpg
#   inflating: ./data/celeba/images/065081.jpg
#   inflating: ./data/celeba/images/156648.jpg
#   inflating: ./data/celeba/images/163764.jpg
#   inflating: ./data/celeba/images/119842.jpg
#   inflating: ./data/celeba/images/085157.jpg
#   inflating: ./data/celeba/images/138167.jpg
#   inflating: ./data/celeba/images/012079.jpg
#   inflating: ./data/celeba/images/141022.jpg
#   inflating: ./data/celeba/images/122130.jpg
#   inflating: ./data/celeba/images/117230.jpg
#   inflating: ./data/celeba/images/192362.jpg
#   inflating: ./data/celeba/images/021443.jpg
#   inflating: ./data/celeba/images/108021.jpg
#   inflating: ./data/celeba/images/184645.jpg
#   inflating: ./data/celeba/images/066848.jpg
#   inflating: ./data/celeba/images/075396.jpg
#   inflating: ./data/celeba/images/172325.jpg
#   inflating: ./data/celeba/images/143935.jpg
#   inflating: ./data/celeba/images/152528.jpg
#   inflating: ./data/celeba/images/004595.jpg
#   inflating: ./data/celeba/images/105852.jpg
#   inflating: ./data/celeba/images/015248.jpg
#   inflating: ./data/celeba/images/196750.jpg
#   inflating: ./data/celeba/images/166746.jpg
#   inflating: ./data/celeba/images/179113.jpg
#   inflating: ./data/celeba/images/079219.jpg
#   inflating: ./data/celeba/images/199197.jpg
#   inflating: ./data/celeba/images/075468.jpg
#   inflating: ./data/celeba/images/191283.jpg
#   inflating: ./data/celeba/images/119917.jpg
#   inflating: ./data/celeba/images/153811.jpg
#   inflating: ./data/celeba/images/029695.jpg
#   inflating: ./data/celeba/images/130692.jpg
#   inflating: ./data/celeba/images/176129.jpg
#   inflating: ./data/celeba/images/051111.jpg
#   inflating: ./data/celeba/images/144638.jpg
#   inflating: ./data/celeba/images/024290.jpg
#   inflating: ./data/celeba/images/101362.jpg
#   inflating: ./data/celeba/images/183830.jpg
#   inflating: ./data/celeba/images/149332.jpg
#   inflating: ./data/celeba/images/110649.jpg
#   inflating: ./data/celeba/images/098903.jpg
#   inflating: ./data/celeba/images/143453.jpg
#   inflating: ./data/celeba/images/007755.jpg
#   inflating: ./data/celeba/images/170813.jpg
#   inflating: ./data/celeba/images/018890.jpg
#   inflating: ./data/celeba/images/115789.jpg
#   inflating: ./data/celeba/images/154663.jpg
#   inflating: ./data/celeba/images/197103.jpg
#   inflating: ./data/celeba/images/175657.jpg
#   inflating: ./data/celeba/images/016927.jpg
#   inflating: ./data/celeba/images/107408.jpg
#   inflating: ./data/celeba/images/080846.jpg
#   inflating: ./data/celeba/images/083657.jpg
#   inflating: ./data/celeba/images/183641.jpg
#   inflating: ./data/celeba/images/138174.jpg
#   inflating: ./data/celeba/images/086649.jpg
#   inflating: ./data/celeba/images/110615.jpg
#   inflating: ./data/celeba/images/197909.jpg
#   inflating: ./data/celeba/images/107447.jpg
#   inflating: ./data/celeba/images/145854.jpg
#   inflating: ./data/celeba/images/117098.jpg
#   inflating: ./data/celeba/images/032422.jpg
#   inflating: ./data/celeba/images/166929.jpg
#   inflating: ./data/celeba/images/028526.jpg
#   inflating: ./data/celeba/images/094577.jpg
#   inflating: ./data/celeba/images/156697.jpg
#   inflating: ./data/celeba/images/000239.jpg
#   inflating: ./data/celeba/images/058479.jpg
#   inflating: ./data/celeba/images/101662.jpg
#   inflating: ./data/celeba/images/081395.jpg
#   inflating: ./data/celeba/images/169392.jpg
#   inflating: ./data/celeba/images/048072.jpg
#   inflating: ./data/celeba/images/121311.jpg
#   inflating: ./data/celeba/images/108845.jpg
#   inflating: ./data/celeba/images/120591.jpg
#   inflating: ./data/celeba/images/073090.jpg
#   inflating: ./data/celeba/images/196307.jpg
#   inflating: ./data/celeba/images/158302.jpg
#   inflating: ./data/celeba/images/176552.jpg
#   inflating: ./data/celeba/images/199698.jpg
#   inflating: ./data/celeba/images/107582.jpg
#   inflating: ./data/celeba/images/126110.jpg
#   inflating: ./data/celeba/images/023458.jpg
#   inflating: ./data/celeba/images/195996.jpg
#   inflating: ./data/celeba/images/007643.jpg
#   inflating: ./data/celeba/images/054811.jpg
#   inflating: ./data/celeba/images/006644.jpg
#   inflating: ./data/celeba/images/122159.jpg
#   inflating: ./data/celeba/images/077196.jpg
#   inflating: ./data/celeba/images/075700.jpg
#   inflating: ./data/celeba/images/043892.jpg
#   inflating: ./data/celeba/images/137979.jpg
#   inflating: ./data/celeba/images/120304.jpg
#   inflating: ./data/celeba/images/040412.jpg
#   inflating: ./data/celeba/images/115532.jpg
#   inflating: ./data/celeba/images/201232.jpg
#   inflating: ./data/celeba/images/129411.jpg
#   inflating: ./data/celeba/images/148545.jpg
#   inflating: ./data/celeba/images/172860.jpg
#   inflating: ./data/celeba/images/046375.jpg
#   inflating: ./data/celeba/images/099926.jpg
#   inflating: ./data/celeba/images/111482.jpg
#   inflating: ./data/celeba/images/032067.jpg
#   inflating: ./data/celeba/images/014716.jpg
#   inflating: ./data/celeba/images/077019.jpg
#   inflating: ./data/celeba/images/081642.jpg
#   inflating: ./data/celeba/images/178647.jpg
#   inflating: ./data/celeba/images/200511.jpg
#   inflating: ./data/celeba/images/087189.jpg
#   inflating: ./data/celeba/images/116280.jpg
#   inflating: ./data/celeba/images/181818.jpg
#   inflating: ./data/celeba/images/035707.jpg
#   inflating: ./data/celeba/images/052484.jpg
#   inflating: ./data/celeba/images/173911.jpg
#   inflating: ./data/celeba/images/167497.jpg
#   inflating: ./data/celeba/images/181133.jpg
#   inflating: ./data/celeba/images/192549.jpg
#   inflating: ./data/celeba/images/047241.jpg
#   inflating: ./data/celeba/images/083860.jpg
#   inflating: ./data/celeba/images/154001.jpg
#   inflating: ./data/celeba/images/187469.jpg
#   inflating: ./data/celeba/images/147436.jpg
#   inflating: ./data/celeba/images/162697.jpg
#   inflating: ./data/celeba/images/087530.jpg
#   inflating: ./data/celeba/images/034854.jpg
#   inflating: ./data/celeba/images/142487.jpg
#   inflating: ./data/celeba/images/187231.jpg
#   inflating: ./data/celeba/images/146172.jpg
#   inflating: ./data/celeba/images/027492.jpg
#   inflating: ./data/celeba/images/149741.jpg
#   inflating: ./data/celeba/images/015552.jpg
#   inflating: ./data/celeba/images/042446.jpg
#   inflating: ./data/celeba/images/045819.jpg
#   inflating: ./data/celeba/images/085489.jpg
#   inflating: ./data/celeba/images/145212.jpg
#   inflating: ./data/celeba/images/010343.jpg
#   inflating: ./data/celeba/images/127729.jpg
#   inflating: ./data/celeba/images/051253.jpg
#   inflating: ./data/celeba/images/102032.jpg
#   inflating: ./data/celeba/images/187634.jpg
#   inflating: ./data/celeba/images/154120.jpg
#   inflating: ./data/celeba/images/195027.jpg
#   inflating: ./data/celeba/images/017974.jpg
#   inflating: ./data/celeba/images/164480.jpg
#   inflating: ./data/celeba/images/093581.jpg
#   inflating: ./data/celeba/images/028168.jpg
#   inflating: ./data/celeba/images/122940.jpg
#   inflating: ./data/celeba/images/031957.jpg
#   inflating: ./data/celeba/images/062274.jpg
#   inflating: ./data/celeba/images/017811.jpg
#   inflating: ./data/celeba/images/156158.jpg
#   inflating: ./data/celeba/images/073761.jpg
#   inflating: ./data/celeba/images/167391.jpg
#   inflating: ./data/celeba/images/043179.jpg
#   inflating: ./data/celeba/images/085053.jpg
#   inflating: ./data/celeba/images/093863.jpg
#   inflating: ./data/celeba/images/141118.jpg
#   inflating: ./data/celeba/images/022707.jpg
#   inflating: ./data/celeba/images/129796.jpg
#   inflating: ./data/celeba/images/139285.jpg
#   inflating: ./data/celeba/images/070232.jpg
#   inflating: ./data/celeba/images/032394.jpg
#   inflating: ./data/celeba/images/043886.jpg
#   inflating: ./data/celeba/images/025403.jpg
#   inflating: ./data/celeba/images/152245.jpg
#   inflating: ./data/celeba/images/016040.jpg
#   inflating: ./data/celeba/images/129773.jpg
#   inflating: ./data/celeba/images/174573.jpg
#   inflating: ./data/celeba/images/199722.jpg
#   inflating: ./data/celeba/images/021096.jpg
#   inflating: ./data/celeba/images/049983.jpg
#   inflating: ./data/celeba/images/115588.jpg
#   inflating: ./data/celeba/images/184891.jpg
#   inflating: ./data/celeba/images/168652.jpg
#   inflating: ./data/celeba/images/200329.jpg
#   inflating: ./data/celeba/images/165255.jpg
#   inflating: ./data/celeba/images/063100.jpg
#   inflating: ./data/celeba/images/045765.jpg
#   inflating: ./data/celeba/images/059369.jpg
#   inflating: ./data/celeba/images/089104.jpg
#   inflating: ./data/celeba/images/039741.jpg
#   inflating: ./data/celeba/images/057431.jpg
#   inflating: ./data/celeba/images/115318.jpg
#   inflating: ./data/celeba/images/004119.jpg
#   inflating: ./data/celeba/images/058107.jpg
#   inflating: ./data/celeba/images/015622.jpg
#   inflating: ./data/celeba/images/011141.jpg
#   inflating: ./data/celeba/images/181289.jpg
#   inflating: ./data/celeba/images/011052.jpg
#   inflating: ./data/celeba/images/182539.jpg
#   inflating: ./data/celeba/images/062732.jpg
#   inflating: ./data/celeba/images/007828.jpg
#   inflating: ./data/celeba/images/132490.jpg
#   inflating: ./data/celeba/images/148140.jpg
#   inflating: ./data/celeba/images/049440.jpg
#   inflating: ./data/celeba/images/187749.jpg
#   inflating: ./data/celeba/images/180191.jpg
#   inflating: ./data/celeba/images/182022.jpg
#   inflating: ./data/celeba/images/164441.jpg
#   inflating: ./data/celeba/images/109478.jpg
#   inflating: ./data/celeba/images/097994.jpg
#   inflating: ./data/celeba/images/164434.jpg
#   inflating: ./data/celeba/images/015073.jpg
#   inflating: ./data/celeba/images/155000.jpg
#   inflating: ./data/celeba/images/165099.jpg
#   inflating: ./data/celeba/images/057409.jpg
#   inflating: ./data/celeba/images/060293.jpg
#   inflating: ./data/celeba/images/183475.jpg
#   inflating: ./data/celeba/images/046484.jpg
#   inflating: ./data/celeba/images/014305.jpg
#   inflating: ./data/celeba/images/018877.jpg
#   inflating: ./data/celeba/images/157712.jpg
#   inflating: ./data/celeba/images/172882.jpg
#   inflating: ./data/celeba/images/070994.jpg
#   inflating: ./data/celeba/images/184847.jpg
#   inflating: ./data/celeba/images/200020.jpg
#   inflating: ./data/celeba/images/069438.jpg
#   inflating: ./data/celeba/images/016835.jpg
#   inflating: ./data/celeba/images/164825.jpg
#   inflating: ./data/celeba/images/058285.jpg
#   inflating: ./data/celeba/images/105694.jpg
#   inflating: ./data/celeba/images/018781.jpg
#   inflating: ./data/celeba/images/192633.jpg
#   inflating: ./data/celeba/images/110139.jpg
#   inflating: ./data/celeba/images/071466.jpg
#   inflating: ./data/celeba/images/014536.jpg
#   inflating: ./data/celeba/images/176874.jpg
#   inflating: ./data/celeba/images/021937.jpg
#   inflating: ./data/celeba/images/110043.jpg
#   inflating: ./data/celeba/images/111743.jpg
#   inflating: ./data/celeba/images/200328.jpg
#   inflating: ./data/celeba/images/082162.jpg
#   inflating: ./data/celeba/images/140593.jpg
#   inflating: ./data/celeba/images/198049.jpg
#   inflating: ./data/celeba/images/102322.jpg
#   inflating: ./data/celeba/images/183981.jpg
#   inflating: ./data/celeba/images/113341.jpg
#   inflating: ./data/celeba/images/154921.jpg
#   inflating: ./data/celeba/images/195828.jpg
#   inflating: ./data/celeba/images/095123.jpg
#   inflating: ./data/celeba/images/034394.jpg
#   inflating: ./data/celeba/images/104333.jpg
#   inflating: ./data/celeba/images/025183.jpg
#   inflating: ./data/celeba/images/106123.jpg
#   inflating: ./data/celeba/images/011995.jpg
#   inflating: ./data/celeba/images/022738.jpg
#   inflating: ./data/celeba/images/108458.jpg
#   inflating: ./data/celeba/images/105935.jpg
#   inflating: ./data/celeba/images/120208.jpg
#   inflating: ./data/celeba/images/078611.jpg
#   inflating: ./data/celeba/images/049746.jpg
#   inflating: ./data/celeba/images/034704.jpg
#   inflating: ./data/celeba/images/176247.jpg
#   inflating: ./data/celeba/images/170117.jpg
#   inflating: ./data/celeba/images/062075.jpg
#   inflating: ./data/celeba/images/056407.jpg
#   inflating: ./data/celeba/images/089883.jpg
#   inflating: ./data/celeba/images/012031.jpg
#   inflating: ./data/celeba/images/003646.jpg
#   inflating: ./data/celeba/images/136091.jpg
#   inflating: ./data/celeba/images/121500.jpg
#   inflating: ./data/celeba/images/070691.jpg
#   inflating: ./data/celeba/images/016830.jpg
#   inflating: ./data/celeba/images/027243.jpg
#   inflating: ./data/celeba/images/112536.jpg
#   inflating: ./data/celeba/images/107883.jpg
#   inflating: ./data/celeba/images/136553.jpg
#   inflating: ./data/celeba/images/171790.jpg
#   inflating: ./data/celeba/images/012663.jpg
#   inflating: ./data/celeba/images/037259.jpg
#   inflating: ./data/celeba/images/125197.jpg
#   inflating: ./data/celeba/images/104996.jpg
#   inflating: ./data/celeba/images/179008.jpg
#   inflating: ./data/celeba/images/185757.jpg
#   inflating: ./data/celeba/images/045642.jpg
#   inflating: ./data/celeba/images/078651.jpg
#   inflating: ./data/celeba/images/057041.jpg
#   inflating: ./data/celeba/images/185756.jpg
#   inflating: ./data/celeba/images/049621.jpg
#   inflating: ./data/celeba/images/184472.jpg
#   inflating: ./data/celeba/images/133349.jpg
#   inflating: ./data/celeba/images/072626.jpg
#   inflating: ./data/celeba/images/055894.jpg
#   inflating: ./data/celeba/images/180422.jpg
#   inflating: ./data/celeba/images/141769.jpg
#   inflating: ./data/celeba/images/059562.jpg
#   inflating: ./data/celeba/images/123523.jpg
#   inflating: ./data/celeba/images/158999.jpg
#   inflating: ./data/celeba/images/015224.jpg
#   inflating: ./data/celeba/images/020277.jpg
#   inflating: ./data/celeba/images/152743.jpg
#   inflating: ./data/celeba/images/028987.jpg
#   inflating: ./data/celeba/images/133482.jpg
#   inflating: ./data/celeba/images/154618.jpg
#   inflating: ./data/celeba/images/182031.jpg
#   inflating: ./data/celeba/images/155916.jpg
#   inflating: ./data/celeba/images/123509.jpg
#   inflating: ./data/celeba/images/079183.jpg
#   inflating: ./data/celeba/images/147745.jpg
#   inflating: ./data/celeba/images/107905.jpg
#   inflating: ./data/celeba/images/077205.jpg
#   inflating: ./data/celeba/images/019147.jpg
#   inflating: ./data/celeba/images/195140.jpg
#   inflating: ./data/celeba/images/090380.jpg
#   inflating: ./data/celeba/images/022393.jpg
#   inflating: ./data/celeba/images/164539.jpg
#   inflating: ./data/celeba/images/042584.jpg
#   inflating: ./data/celeba/images/164009.jpg
#   inflating: ./data/celeba/images/026915.jpg
#   inflating: ./data/celeba/images/077336.jpg
#   inflating: ./data/celeba/images/080727.jpg
#   inflating: ./data/celeba/images/050420.jpg
#   inflating: ./data/celeba/images/066953.jpg
#   inflating: ./data/celeba/images/107909.jpg
#   inflating: ./data/celeba/images/201663.jpg
#   inflating: ./data/celeba/images/060484.jpg
#   inflating: ./data/celeba/images/095692.jpg
#   inflating: ./data/celeba/images/112189.jpg
#   inflating: ./data/celeba/images/049413.jpg
#   inflating: ./data/celeba/images/020442.jpg
#   inflating: ./data/celeba/images/085706.jpg
#   inflating: ./data/celeba/images/133194.jpg
#   inflating: ./data/celeba/images/051307.jpg
#   inflating: ./data/celeba/images/000726.jpg
#   inflating: ./data/celeba/images/045393.jpg
#   inflating: ./data/celeba/images/063557.jpg
#   inflating: ./data/celeba/images/129712.jpg
#   inflating: ./data/celeba/images/017553.jpg
#   inflating: ./data/celeba/images/091914.jpg
#   inflating: ./data/celeba/images/106880.jpg
#   inflating: ./data/celeba/images/041096.jpg
#   inflating: ./data/celeba/images/202311.jpg
#   inflating: ./data/celeba/images/066776.jpg
#   inflating: ./data/celeba/images/148853.jpg
#   inflating: ./data/celeba/images/102993.jpg
#   inflating: ./data/celeba/images/140596.jpg
#   inflating: ./data/celeba/images/170532.jpg
#   inflating: ./data/celeba/images/103134.jpg
#   inflating: ./data/celeba/images/175677.jpg
#   inflating: ./data/celeba/images/046938.jpg
#   inflating: ./data/celeba/images/049324.jpg
#   inflating: ./data/celeba/images/134641.jpg
#   inflating: ./data/celeba/images/006271.jpg
#   inflating: ./data/celeba/images/070601.jpg
#   inflating: ./data/celeba/images/087291.jpg
#   inflating: ./data/celeba/images/076279.jpg
#   inflating: ./data/celeba/images/083377.jpg
#   inflating: ./data/celeba/images/004587.jpg
#   inflating: ./data/celeba/images/051239.jpg
#   inflating: ./data/celeba/images/073574.jpg
#   inflating: ./data/celeba/images/018880.jpg
#   inflating: ./data/celeba/images/077093.jpg
#   inflating: ./data/celeba/images/017625.jpg
#   inflating: ./data/celeba/images/152948.jpg
#   inflating: ./data/celeba/images/005750.jpg
#   inflating: ./data/celeba/images/137759.jpg
#   inflating: ./data/celeba/images/071532.jpg
#   inflating: ./data/celeba/images/015713.jpg
#   inflating: ./data/celeba/images/161261.jpg
#   inflating: ./data/celeba/images/131520.jpg
#   inflating: ./data/celeba/images/155501.jpg
#   inflating: ./data/celeba/images/158595.jpg
#   inflating: ./data/celeba/images/058067.jpg
#   inflating: ./data/celeba/images/073596.jpg
#   inflating: ./data/celeba/images/019676.jpg
#   inflating: ./data/celeba/images/105101.jpg
#   inflating: ./data/celeba/images/156896.jpg
#   inflating: ./data/celeba/images/043708.jpg
#   inflating: ./data/celeba/images/040092.jpg
#   inflating: ./data/celeba/images/098892.jpg
#   inflating: ./data/celeba/images/044575.jpg
#   inflating: ./data/celeba/images/008508.jpg
#   inflating: ./data/celeba/images/065553.jpg
#   inflating: ./data/celeba/images/073956.jpg
#   inflating: ./data/celeba/images/055168.jpg
#   inflating: ./data/celeba/images/095326.jpg
#   inflating: ./data/celeba/images/008512.jpg
#   inflating: ./data/celeba/images/192933.jpg
#   inflating: ./data/celeba/images/167294.jpg
#   inflating: ./data/celeba/images/032857.jpg
#   inflating: ./data/celeba/images/175078.jpg
#   inflating: ./data/celeba/images/162432.jpg
#   inflating: ./data/celeba/images/092331.jpg
#   inflating: ./data/celeba/images/060175.jpg
#   inflating: ./data/celeba/images/029433.jpg
#   inflating: ./data/celeba/images/033132.jpg
#   inflating: ./data/celeba/images/068208.jpg
#   inflating: ./data/celeba/images/184685.jpg
#   inflating: ./data/celeba/images/196714.jpg
#   inflating: ./data/celeba/images/100809.jpg
#   inflating: ./data/celeba/images/182190.jpg
#   inflating: ./data/celeba/images/115691.jpg
#   inflating: ./data/celeba/images/102755.jpg
#   inflating: ./data/celeba/images/121183.jpg
#   inflating: ./data/celeba/images/162861.jpg
#   inflating: ./data/celeba/images/156388.jpg
#   inflating: ./data/celeba/images/013899.jpg
#   inflating: ./data/celeba/images/018013.jpg
#   inflating: ./data/celeba/images/199412.jpg
#   inflating: ./data/celeba/images/007299.jpg
#   inflating: ./data/celeba/images/170941.jpg
#   inflating: ./data/celeba/images/128264.jpg
#   inflating: ./data/celeba/images/059949.jpg
#   inflating: ./data/celeba/images/012605.jpg
#   inflating: ./data/celeba/images/002324.jpg
#   inflating: ./data/celeba/images/110756.jpg
#   inflating: ./data/celeba/images/146315.jpg
#   inflating: ./data/celeba/images/155603.jpg
#   inflating: ./data/celeba/images/190388.jpg
#   inflating: ./data/celeba/images/073331.jpg
#   inflating: ./data/celeba/images/032616.jpg
#   inflating: ./data/celeba/images/178563.jpg
#   inflating: ./data/celeba/images/148164.jpg
#   inflating: ./data/celeba/images/087973.jpg
#   inflating: ./data/celeba/images/048879.jpg
#   inflating: ./data/celeba/images/022156.jpg
#   inflating: ./data/celeba/images/187213.jpg
#   inflating: ./data/celeba/images/202012.jpg
#   inflating: ./data/celeba/images/135446.jpg
#   inflating: ./data/celeba/images/188237.jpg
#   inflating: ./data/celeba/images/158585.jpg
#   inflating: ./data/celeba/images/064622.jpg
#   inflating: ./data/celeba/images/020240.jpg
#   inflating: ./data/celeba/images/108282.jpg
#   inflating: ./data/celeba/images/195734.jpg
#   inflating: ./data/celeba/images/168937.jpg
#   inflating: ./data/celeba/images/074926.jpg
#   inflating: ./data/celeba/images/080361.jpg
#   inflating: ./data/celeba/images/006627.jpg
#   inflating: ./data/celeba/images/054666.jpg
#   inflating: ./data/celeba/images/106772.jpg
#   inflating: ./data/celeba/images/141020.jpg
#   inflating: ./data/celeba/images/117665.jpg
#   inflating: ./data/celeba/images/153652.jpg
#   inflating: ./data/celeba/images/165439.jpg
#   inflating: ./data/celeba/images/173000.jpg
#   inflating: ./data/celeba/images/020357.jpg
#   inflating: ./data/celeba/images/056526.jpg
#   inflating: ./data/celeba/images/186571.jpg
#   inflating: ./data/celeba/images/124019.jpg
#   inflating: ./data/celeba/images/130184.jpg
#   inflating: ./data/celeba/images/029504.jpg
#   inflating: ./data/celeba/images/116683.jpg
#   inflating: ./data/celeba/images/065437.jpg
#   inflating: ./data/celeba/images/122632.jpg
#   inflating: ./data/celeba/images/016599.jpg
#   inflating: ./data/celeba/images/093691.jpg
#   inflating: ./data/celeba/images/051176.jpg
#   inflating: ./data/celeba/images/127745.jpg
#   inflating: ./data/celeba/images/169223.jpg
#   inflating: ./data/celeba/images/184395.jpg
#   inflating: ./data/celeba/images/075519.jpg
#   inflating: ./data/celeba/images/167355.jpg
#   inflating: ./data/celeba/images/183341.jpg
#   inflating: ./data/celeba/images/132607.jpg
#   inflating: ./data/celeba/images/149409.jpg
#   inflating: ./data/celeba/images/062421.jpg
#   inflating: ./data/celeba/images/121355.jpg
#   inflating: ./data/celeba/images/174006.jpg
#   inflating: ./data/celeba/images/006516.jpg
#   inflating: ./data/celeba/images/118948.jpg
#   inflating: ./data/celeba/images/201666.jpg
#   inflating: ./data/celeba/images/065447.jpg
#   inflating: ./data/celeba/images/055581.jpg
#   inflating: ./data/celeba/images/184479.jpg
#   inflating: ./data/celeba/images/202176.jpg
#   inflating: ./data/celeba/images/121590.jpg
#   inflating: ./data/celeba/images/085452.jpg
#   inflating: ./data/celeba/images/016883.jpg
#   inflating: ./data/celeba/images/125332.jpg
#   inflating: ./data/celeba/images/099969.jpg
#   inflating: ./data/celeba/images/094008.jpg
#   inflating: ./data/celeba/images/010781.jpg
#   inflating: ./data/celeba/images/155177.jpg
#   inflating: ./data/celeba/images/080746.jpg
#   inflating: ./data/celeba/images/155947.jpg
#   inflating: ./data/celeba/images/202061.jpg
#   inflating: ./data/celeba/images/119745.jpg
#   inflating: ./data/celeba/images/176319.jpg
#   inflating: ./data/celeba/images/118575.jpg
#   inflating: ./data/celeba/images/051468.jpg
#   inflating: ./data/celeba/images/049151.jpg
#   inflating: ./data/celeba/images/109015.jpg
#   inflating: ./data/celeba/images/096319.jpg
#   inflating: ./data/celeba/images/081171.jpg
#   inflating: ./data/celeba/images/037117.jpg
#   inflating: ./data/celeba/images/135078.jpg
#   inflating: ./data/celeba/images/167641.jpg
#   inflating: ./data/celeba/images/196526.jpg
#   inflating: ./data/celeba/images/093792.jpg
#   inflating: ./data/celeba/images/135283.jpg
#   inflating: ./data/celeba/images/190463.jpg
#   inflating: ./data/celeba/images/189503.jpg
#   inflating: ./data/celeba/images/198687.jpg
#   inflating: ./data/celeba/images/071769.jpg
#   inflating: ./data/celeba/images/153140.jpg
#   inflating: ./data/celeba/images/113578.jpg
#   inflating: ./data/celeba/images/041935.jpg
#   inflating: ./data/celeba/images/026204.jpg
#   inflating: ./data/celeba/images/080189.jpg
#   inflating: ./data/celeba/images/166226.jpg
#   inflating: ./data/celeba/images/133999.jpg
#   inflating: ./data/celeba/images/088778.jpg
#   inflating: ./data/celeba/images/113968.jpg
#   inflating: ./data/celeba/images/064338.jpg
#   inflating: ./data/celeba/images/091333.jpg
#   inflating: ./data/celeba/images/097319.jpg
#   inflating: ./data/celeba/images/112574.jpg
#   inflating: ./data/celeba/images/153577.jpg
#   inflating: ./data/celeba/images/022174.jpg
#   inflating: ./data/celeba/images/192395.jpg
#   inflating: ./data/celeba/images/189538.jpg
#   inflating: ./data/celeba/images/170906.jpg
#   inflating: ./data/celeba/images/103368.jpg
#   inflating: ./data/celeba/images/143432.jpg
#   inflating: ./data/celeba/images/050514.jpg
#   inflating: ./data/celeba/images/154235.jpg
#   inflating: ./data/celeba/images/070705.jpg
#   inflating: ./data/celeba/images/014053.jpg
#   inflating: ./data/celeba/images/067418.jpg
#   inflating: ./data/celeba/images/169539.jpg
#   inflating: ./data/celeba/images/075682.jpg
#   inflating: ./data/celeba/images/031900.jpg
#   inflating: ./data/celeba/images/157503.jpg
#   inflating: ./data/celeba/images/130571.jpg
#   inflating: ./data/celeba/images/039320.jpg
#   inflating: ./data/celeba/images/078764.jpg
#   inflating: ./data/celeba/images/186303.jpg
#   inflating: ./data/celeba/images/124438.jpg
#   inflating: ./data/celeba/images/138360.jpg
#   inflating: ./data/celeba/images/154700.jpg
#   inflating: ./data/celeba/images/003224.jpg
#   inflating: ./data/celeba/images/068399.jpg
#   inflating: ./data/celeba/images/022986.jpg
#   inflating: ./data/celeba/images/193727.jpg
#   inflating: ./data/celeba/images/110227.jpg
#   inflating: ./data/celeba/images/144347.jpg
#   inflating: ./data/celeba/images/000529.jpg
# ...
#   inflating: ./data/celeba/images/073819.jpg
#   inflating: ./data/celeba/images/115327.jpg
#   inflating: ./data/celeba/images/033320.jpg
#   inflating: ./data/celeba/images/095439.jpg
#   inflating: ./data/celeba/images/051001.jpg
#   inflating: ./data/celeba/images/177335.jpg
#   inflating: ./data/celeba/images/171547.jpg
#   inflating: ./data/celeba/images/110229.jpg
#   inflating: ./data/celeba/images/030856.jpg
#   inflating: ./data/celeba/images/102558.jpg
#   inflating: ./data/celeba/images/135875.jpg
#   inflating: ./data/celeba/images/061533.jpg
#   inflating: ./data/celeba/images/067384.jpg
#   inflating: ./data/celeba/images/035000.jpg
#   inflating: ./data/celeba/images/160156.jpg
#   inflating: ./data/celeba/images/002606.jpg
#   inflating: ./data/celeba/images/177705.jpg
#   inflating: ./data/celeba/images/163500.jpg
#   inflating: ./data/celeba/images/058132.jpg
#   inflating: ./data/celeba/images/024024.jpg
#   inflating: ./data/celeba/images/095383.jpg
#   inflating: ./data/celeba/images/167194.jpg
#   inflating: ./data/celeba/images/183479.jpg
#   inflating: ./data/celeba/images/158493.jpg
#   inflating: ./data/celeba/images/173715.jpg
#   inflating: ./data/celeba/images/068080.jpg
#   inflating: ./data/celeba/images/169256.jpg
#   inflating: ./data/celeba/images/044003.jpg
#   inflating: ./data/celeba/images/147764.jpg
#   inflating: ./data/celeba/images/061476.jpg
#   inflating: ./data/celeba/images/136885.jpg
#   inflating: ./data/celeba/images/014076.jpg
#   inflating: ./data/celeba/images/109230.jpg
#   inflating: ./data/celeba/images/010451.jpg
#   inflating: ./data/celeba/images/137231.jpg
#   inflating: ./data/celeba/images/111758.jpg
#   inflating: ./data/celeba/images/094585.jpg
#   inflating: ./data/celeba/images/017919.jpg
#   inflating: ./data/celeba/images/094638.jpg
#   inflating: ./data/celeba/images/086681.jpg
#   inflating: ./data/celeba/images/165882.jpg
#   inflating: ./data/celeba/images/199733.jpg
#   inflating: ./data/celeba/images/172492.jpg
#   inflating: ./data/celeba/images/093738.jpg
#   inflating: ./data/celeba/images/150068.jpg
#   inflating: ./data/celeba/images/173926.jpg
#   inflating: ./data/celeba/images/081281.jpg
#   inflating: ./data/celeba/images/180403.jpg
#   inflating: ./data/celeba/images/078761.jpg
#   inflating: ./data/celeba/images/199242.jpg
#   inflating: ./data/celeba/images/014850.jpg
#   inflating: ./data/celeba/images/007804.jpg
#   inflating: ./data/celeba/images/046399.jpg
#   inflating: ./data/celeba/images/041186.jpg
#   inflating: ./data/celeba/images/018174.jpg
#   inflating: ./data/celeba/images/107245.jpg
#   inflating: ./data/celeba/images/022715.jpg
#   inflating: ./data/celeba/images/088212.jpg
#   inflating: ./data/celeba/images/003888.jpg
#   inflating: ./data/celeba/images/081536.jpg
#   inflating: ./data/celeba/images/096158.jpg
#   inflating: ./data/celeba/images/114918.jpg
#   inflating: ./data/celeba/images/047297.jpg
#   inflating: ./data/celeba/images/135983.jpg
#   inflating: ./data/celeba/images/111197.jpg
#   inflating: ./data/celeba/images/130937.jpg
#   inflating: ./data/celeba/images/175355.jpg
#   inflating: ./data/celeba/images/112797.jpg
#   inflating: ./data/celeba/images/077271.jpg
#   inflating: ./data/celeba/images/021228.jpg
#   inflating: ./data/celeba/images/083765.jpg
#   inflating: ./data/celeba/images/202532.jpg
#   inflating: ./data/celeba/images/166688.jpg
#   inflating: ./data/celeba/images/094356.jpg
#   inflating: ./data/celeba/images/168855.jpg
#   inflating: ./data/celeba/images/117556.jpg
#   inflating: ./data/celeba/images/043674.jpg
#   inflating: ./data/celeba/images/101410.jpg
#   inflating: ./data/celeba/images/153452.jpg
#   inflating: ./data/celeba/images/010713.jpg
#   inflating: ./data/celeba/images/040171.jpg
#   inflating: ./data/celeba/images/082961.jpg
#   inflating: ./data/celeba/images/013950.jpg
#   inflating: ./data/celeba/images/179621.jpg
#   inflating: ./data/celeba/images/183279.jpg
#   inflating: ./data/celeba/images/016988.jpg
#   inflating: ./data/celeba/images/140023.jpg
#   inflating: ./data/celeba/images/170754.jpg
#   inflating: ./data/celeba/images/120633.jpg
#   inflating: ./data/celeba/images/030741.jpg
#   inflating: ./data/celeba/images/160897.jpg
#   inflating: ./data/celeba/images/117411.jpg
#   inflating: ./data/celeba/images/193847.jpg
#   inflating: ./data/celeba/images/007257.jpg
#   inflating: ./data/celeba/images/130637.jpg
#   inflating: ./data/celeba/images/077611.jpg
#   inflating: ./data/celeba/images/001922.jpg
#   inflating: ./data/celeba/images/189898.jpg
#   inflating: ./data/celeba/images/044850.jpg
#   inflating: ./data/celeba/images/072822.jpg
#   inflating: ./data/celeba/images/098625.jpg
#   inflating: ./data/celeba/images/051070.jpg
#   inflating: ./data/celeba/images/077948.jpg
#   inflating: ./data/celeba/images/166706.jpg
#   inflating: ./data/celeba/images/119884.jpg
#   inflating: ./data/celeba/images/039965.jpg
#   inflating: ./data/celeba/images/034611.jpg
#   inflating: ./data/celeba/images/070072.jpg
#   inflating: ./data/celeba/images/193226.jpg
#   inflating: ./data/celeba/images/020993.jpg
#   inflating: ./data/celeba/images/062936.jpg
#   inflating: ./data/celeba/images/091237.jpg
#   inflating: ./data/celeba/images/123496.jpg
#   inflating: ./data/celeba/images/054735.jpg
#   inflating: ./data/celeba/images/008140.jpg
#   inflating: ./data/celeba/images/009505.jpg
#   inflating: ./data/celeba/images/048983.jpg
#   inflating: ./data/celeba/images/185527.jpg
#   inflating: ./data/celeba/images/102179.jpg
#   inflating: ./data/celeba/images/087968.jpg
#   inflating: ./data/celeba/images/068258.jpg
#   inflating: ./data/celeba/images/009998.jpg
#   inflating: ./data/celeba/images/074292.jpg
#   inflating: ./data/celeba/images/163654.jpg
#   inflating: ./data/celeba/images/035979.jpg
#   inflating: ./data/celeba/images/109944.jpg
#   inflating: ./data/celeba/images/143925.jpg
#   inflating: ./data/celeba/images/033906.jpg
#   inflating: ./data/celeba/images/023342.jpg
#   inflating: ./data/celeba/images/018788.jpg
#   inflating: ./data/celeba/images/152451.jpg
#   inflating: ./data/celeba/images/114994.jpg
#   inflating: ./data/celeba/images/014855.jpg
#   inflating: ./data/celeba/images/027728.jpg
#   inflating: ./data/celeba/images/131579.jpg
#   inflating: ./data/celeba/images/025567.jpg
#   inflating: ./data/celeba/images/001709.jpg
#   inflating: ./data/celeba/images/198033.jpg
#   inflating: ./data/celeba/images/089732.jpg
#   inflating: ./data/celeba/images/161877.jpg
#   inflating: ./data/celeba/images/106981.jpg
#   inflating: ./data/celeba/images/143261.jpg
#   inflating: ./data/celeba/images/034706.jpg
#   inflating: ./data/celeba/images/140626.jpg
#   inflating: ./data/celeba/images/130480.jpg
#   inflating: ./data/celeba/images/094670.jpg
#   inflating: ./data/celeba/images/168121.jpg
#   inflating: ./data/celeba/images/001231.jpg
#   inflating: ./data/celeba/images/199385.jpg
#   inflating: ./data/celeba/images/135227.jpg
#   inflating: ./data/celeba/images/146382.jpg
#   inflating: ./data/celeba/images/103825.jpg
#   inflating: ./data/celeba/images/048636.jpg
#   inflating: ./data/celeba/images/108251.jpg
#   inflating: ./data/celeba/images/036921.jpg
#   inflating: ./data/celeba/images/031060.jpg
#   inflating: ./data/celeba/images/059585.jpg
#   inflating: ./data/celeba/images/053758.jpg
#   inflating: ./data/celeba/images/013135.jpg
#   inflating: ./data/celeba/images/060678.jpg
#   inflating: ./data/celeba/images/184502.jpg
#   inflating: ./data/celeba/images/154031.jpg
#   inflating: ./data/celeba/images/111534.jpg
#   inflating: ./data/celeba/images/136967.jpg
#   inflating: ./data/celeba/images/033433.jpg
#   inflating: ./data/celeba/images/000433.jpg
#   inflating: ./data/celeba/images/163972.jpg
#   inflating: ./data/celeba/images/197690.jpg
#   inflating: ./data/celeba/images/108316.jpg
#   inflating: ./data/celeba/images/187030.jpg
#   inflating: ./data/celeba/images/154562.jpg
#   inflating: ./data/celeba/images/008394.jpg
#   inflating: ./data/celeba/images/178862.jpg
#   inflating: ./data/celeba/images/035370.jpg
#   inflating: ./data/celeba/images/007597.jpg
#   inflating: ./data/celeba/images/183506.jpg
#   inflating: ./data/celeba/images/126490.jpg
#   inflating: ./data/celeba/images/134995.jpg
#   inflating: ./data/celeba/images/113351.jpg
#   inflating: ./data/celeba/images/066180.jpg
#   inflating: ./data/celeba/images/037361.jpg
#   inflating: ./data/celeba/images/108716.jpg
#   inflating: ./data/celeba/images/017031.jpg
#   inflating: ./data/celeba/images/107510.jpg
#   inflating: ./data/celeba/images/147254.jpg
#   inflating: ./data/celeba/images/095426.jpg
#   inflating: ./data/celeba/images/138229.jpg
#   inflating: ./data/celeba/images/160910.jpg
#   inflating: ./data/celeba/images/097997.jpg
#   inflating: ./data/celeba/images/100375.jpg
#   inflating: ./data/celeba/images/195158.jpg
#   inflating: ./data/celeba/images/014405.jpg
#   inflating: ./data/celeba/images/058010.jpg
#   inflating: ./data/celeba/images/075327.jpg
#   inflating: ./data/celeba/images/191365.jpg
#   inflating: ./data/celeba/images/061869.jpg
#   inflating: ./data/celeba/images/151234.jpg
#   inflating: ./data/celeba/images/176473.jpg
#   inflating: ./data/celeba/images/097014.jpg
#   inflating: ./data/celeba/images/150773.jpg
#   inflating: ./data/celeba/images/131159.jpg
#   inflating: ./data/celeba/images/143435.jpg
#   inflating: ./data/celeba/images/118126.jpg
#   inflating: ./data/celeba/images/133436.jpg
#   inflating: ./data/celeba/images/123406.jpg
#   inflating: ./data/celeba/images/008321.jpg
#   inflating: ./data/celeba/images/109623.jpg
#   inflating: ./data/celeba/images/059346.jpg
#   inflating: ./data/celeba/images/134261.jpg
#   inflating: ./data/celeba/images/018232.jpg
#   inflating: ./data/celeba/images/118720.jpg
#   inflating: ./data/celeba/images/063717.jpg
#   inflating: ./data/celeba/images/163340.jpg
#   inflating: ./data/celeba/images/070920.jpg
#   inflating: ./data/celeba/images/050828.jpg
#   inflating: ./data/celeba/images/198987.jpg
#   inflating: ./data/celeba/images/096643.jpg
#   inflating: ./data/celeba/images/198936.jpg
#   inflating: ./data/celeba/images/079152.jpg
#   inflating: ./data/celeba/images/054686.jpg
#   inflating: ./data/celeba/images/033699.jpg
#   inflating: ./data/celeba/images/135850.jpg
#   inflating: ./data/celeba/images/169691.jpg
#   inflating: ./data/celeba/images/022009.jpg
#   inflating: ./data/celeba/images/097998.jpg
#   inflating: ./data/celeba/images/138523.jpg
#   inflating: ./data/celeba/images/094174.jpg
#   inflating: ./data/celeba/images/088746.jpg
#   inflating: ./data/celeba/images/088980.jpg
#   inflating: ./data/celeba/images/112127.jpg
#   inflating: ./data/celeba/images/074639.jpg
#   inflating: ./data/celeba/images/178335.jpg
#   inflating: ./data/celeba/images/061816.jpg
#   inflating: ./data/celeba/images/139188.jpg
#   inflating: ./data/celeba/images/154541.jpg
#   inflating: ./data/celeba/images/118965.jpg
#   inflating: ./data/celeba/images/099352.jpg
#   inflating: ./data/celeba/images/049763.jpg
#   inflating: ./data/celeba/images/063370.jpg
#   inflating: ./data/celeba/images/101190.jpg
#   inflating: ./data/celeba/images/053891.jpg
#   inflating: ./data/celeba/images/155965.jpg
#   inflating: ./data/celeba/images/063502.jpg
#   inflating: ./data/celeba/images/086048.jpg
#   inflating: ./data/celeba/images/150479.jpg
#   inflating: ./data/celeba/images/101940.jpg
#   inflating: ./data/celeba/images/117881.jpg
#   inflating: ./data/celeba/images/108704.jpg
#   inflating: ./data/celeba/images/180370.jpg
#   inflating: ./data/celeba/images/138142.jpg
#   inflating: ./data/celeba/images/004016.jpg
#   inflating: ./data/celeba/images/192288.jpg
#   inflating: ./data/celeba/images/113509.jpg
#   inflating: ./data/celeba/images/007105.jpg
#   inflating: ./data/celeba/images/000908.jpg
#   inflating: ./data/celeba/images/147590.jpg
#   inflating: ./data/celeba/images/163299.jpg
#   inflating: ./data/celeba/images/032522.jpg
#   inflating: ./data/celeba/images/020572.jpg
#   inflating: ./data/celeba/images/150704.jpg
#   inflating: ./data/celeba/images/044704.jpg
#   inflating: ./data/celeba/images/015597.jpg
#   inflating: ./data/celeba/images/108885.jpg
#   inflating: ./data/celeba/images/106127.jpg
#   inflating: ./data/celeba/images/179329.jpg
#   inflating: ./data/celeba/images/141141.jpg
#   inflating: ./data/celeba/images/120406.jpg
#   inflating: ./data/celeba/images/004257.jpg
#   inflating: ./data/celeba/images/005657.jpg
#   inflating: ./data/celeba/images/031138.jpg
#   inflating: ./data/celeba/images/065892.jpg
#   inflating: ./data/celeba/images/111742.jpg
#   inflating: ./data/celeba/images/130537.jpg
#   inflating: ./data/celeba/images/015871.jpg
#   inflating: ./data/celeba/images/054839.jpg
#   inflating: ./data/celeba/images/040142.jpg
#   inflating: ./data/celeba/images/153688.jpg
#   inflating: ./data/celeba/images/189591.jpg
#   inflating: ./data/celeba/images/081388.jpg
#   inflating: ./data/celeba/images/011749.jpg
#   inflating: ./data/celeba/images/004283.jpg
#   inflating: ./data/celeba/images/161807.jpg
#   inflating: ./data/celeba/images/169565.jpg
#   inflating: ./data/celeba/images/176169.jpg
#   inflating: ./data/celeba/images/194102.jpg
#   inflating: ./data/celeba/images/151571.jpg
#   inflating: ./data/celeba/images/073234.jpg
#   inflating: ./data/celeba/images/177038.jpg
#   inflating: ./data/celeba/images/123845.jpg
#   inflating: ./data/celeba/images/104780.jpg
#   inflating: ./data/celeba/images/096685.jpg
#   inflating: ./data/celeba/images/014868.jpg
#   inflating: ./data/celeba/images/150052.jpg
#   inflating: ./data/celeba/images/184796.jpg
#   inflating: ./data/celeba/images/050918.jpg
#   inflating: ./data/celeba/images/147116.jpg
#   inflating: ./data/celeba/images/056427.jpg
#   inflating: ./data/celeba/images/076013.jpg
#   inflating: ./data/celeba/images/153134.jpg
#   inflating: ./data/celeba/images/021659.jpg
#   inflating: ./data/celeba/images/039800.jpg
#   inflating: ./data/celeba/images/074956.jpg
#   inflating: ./data/celeba/images/156294.jpg
#   inflating: ./data/celeba/images/146462.jpg
#   inflating: ./data/celeba/images/034551.jpg
#   inflating: ./data/celeba/images/096009.jpg
#   inflating: ./data/celeba/images/125588.jpg
#   inflating: ./data/celeba/images/040085.jpg
#   inflating: ./data/celeba/images/128804.jpg
#   inflating: ./data/celeba/images/012696.jpg
#   inflating: ./data/celeba/images/185642.jpg
#   inflating: ./data/celeba/images/170858.jpg
#   inflating: ./data/celeba/images/152579.jpg
#   inflating: ./data/celeba/images/085734.jpg
#   inflating: ./data/celeba/images/086316.jpg
#   inflating: ./data/celeba/images/176878.jpg
#   inflating: ./data/celeba/images/113766.jpg
#   inflating: ./data/celeba/images/168206.jpg
#   inflating: ./data/celeba/images/087524.jpg
#   inflating: ./data/celeba/images/110914.jpg
#   inflating: ./data/celeba/images/111579.jpg
#   inflating: ./data/celeba/images/187997.jpg
#   inflating: ./data/celeba/images/153599.jpg
#   inflating: ./data/celeba/images/184995.jpg
#   inflating: ./data/celeba/images/056344.jpg
#   inflating: ./data/celeba/images/066478.jpg
#   inflating: ./data/celeba/images/187754.jpg
#   inflating: ./data/celeba/images/170248.jpg
#   inflating: ./data/celeba/images/184677.jpg
#   inflating: ./data/celeba/images/075312.jpg
#   inflating: ./data/celeba/images/080137.jpg
#   inflating: ./data/celeba/images/164412.jpg
#   inflating: ./data/celeba/images/125252.jpg
#   inflating: ./data/celeba/images/012766.jpg
#   inflating: ./data/celeba/images/069249.jpg
#   inflating: ./data/celeba/images/064885.jpg
#   inflating: ./data/celeba/images/134525.jpg
#   inflating: ./data/celeba/images/117341.jpg
#   inflating: ./data/celeba/images/192484.jpg
#   inflating: ./data/celeba/images/167122.jpg

# %%
def split_celeba_dataset(img_path, attr_path, out_dir, split="test"):
    
    """
    split the celebA dataset
    Args:
        img_path (str): image path directory 
        attr_path (str): celebA attribute file path (ex: list_attr_celeba.txt)
        out_dir (str): Path where the split data to be saved
        split (string): split the dataset depends on the split attribute(train, valid, and test)
    """
    # as per the author's remark, we split the dataset
    train_beg = 0  # train starts from
    valid_beg = 162770  # valid starts from
    test_beg = 182610  # test starts from
    
    label_file = open(attr_path, 'r')
    label_file = label_file.readlines()
    
    # skipping the first two rows for header
    total_samples = len(label_file) - 2
    if split == 'train':
        number_samples = valid_beg - train_beg
        beg = train_beg
    
    elif split == 'valid':
        number_samples = test_beg - valid_beg
        beg = valid_beg
    
    elif split == 'test':
        number_samples = total_samples - test_beg
        beg = test_beg
    else:
        print('Error')
        return
    
    if not os.path.exists(out_dir):
        os.makedirs(out_dir)
    
    for i in range(beg + 2, beg + number_samples + 2):
        temp = label_file[i].strip().split()
        src_dir = os.path.join(img_path,temp[0])
        dst_dir = os.path.join(out_dir,temp[0])
        shutil.copy(src_dir, dst_dir)
    print("splitting completed")

# %% [markdown]
# [CelebA](https://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) is a dataset with 2,022,599 celebrity face images, each with 40 binary attributes labels.
#
# Now let us train an `Attractive` classifier that is not dependent on gender expression. `Male` attribute corresponds to gender expression and the target attribute is `Attractive`.

# %%
def data_iterator_celeba(img_path, attr_path, batch_size,
                         target_attribute ='Attractive', protected_attribute = 'Male', 
                         num_samples=-1, augment=False, shuffle=False, rng=None):
    """
    create celebA data iterator
    Args:
        img_path (str) : image path directory
        attr_path (str) : celebA attribute file path (ex: list_attr_celeba.txt)
        batch_size (int) :  number of samples contained in each generated batch
        target_attribute (str) : target attribute (ex: Arched EyeBrows, Bushy Eyebrows, smilling,etc..)
        protected_attribute (str): protected attribute (ex: Male, Pale_Skin)
        num_samples (int) : number of samples taken in data loader
                            (if num_samples=-1, it will take all the images in the dataset)
        augment (bool) : data augmentation (True for training)
        shuffle (bool) : shuffle the data (True /False)
        rng : None
    Returns:
        simple data iterator
    """

    imgs = []
    for file in sorted(os.listdir(img_path), key=lambda x: int(x.split(".")[0])):
        imgs.append(os.path.join(img_path,file))
    with open(attr_path, 'r') as f:
        lines = f.readlines()

    attr_list = lines[1].strip().split()
    attr_idx_dict = {attr: i for i, attr in enumerate(attr_list)}
    labels_dict = {}
    for line in lines[2:]:
        line = line.strip().split()
        key = line[0]
        attr = line[1:]
        labels_dict[key] = np.array([int((int(attr[attr_idx_dict[target_attribute]]) + 1) / 2), int((int(attr[attr_idx_dict[protected_attribute]]) + 1) / 2)])

    # as per the author's citation, we have transformed the input image
    # (resize to , 256×256, 224×224)
    pre_process = [(256, 256), (224, 224)]
    mean_normalize = (0.485, 0.456, 0.406)
    std_normalize = (0.229, 0.224, 0.225)

    if augment:
        transform = A.Compose([
            A.Resize(pre_process[0][0], pre_process[0][1]),
            A.RandomCrop(width=pre_process[1][0], height=pre_process[1][1]),
            A.HorizontalFlip(p=0.5),
            A.Normalize(mean=mean_normalize, std=std_normalize)
        ])
    else:
        transform = A.Compose([
            A.Resize(pre_process[0][0], pre_process[0][1]),
            A.CenterCrop(width=pre_process[1][0], height=pre_process[1][1]),
            A.Normalize(mean=mean_normalize, std=std_normalize)
        ])
    if num_samples == -1:
        num_samples = len(imgs)
    else:
        print("Num. of data ({}) is used for debugging".format(num_samples))

    def load_func(i):
        img = Image.open(imgs[i])
        img = np.array(img.convert('RGB'))
        # transform
        transformed_image = transform(image=img)['image'].transpose(2, 0, 1)
        return transformed_image, labels_dict[os.path.basename(imgs[i])]

    return data_iterator_simple(load_func, num_samples, batch_size, shuffle=shuffle, rng=rng, with_file_cache=False)

# %% [markdown]
# Let’s start with importing basic modules to switch between CPU and GPU.

# %%
from nnabla.ext_utils import get_extension_context
context = "cudnn" # for cpu set context as 'cpu'
device_id = 0
ctx = get_extension_context(context, device_id=device_id)
nn.set_default_context(ctx)

# %% [markdown]
# ### 3. Classifier network
# To train a classifier, we have taken [ResNet-50](https://nnabla.org/pretrained-models/nnp_models/imagenet/Resnet-50/Resnet-50.nnp) pretrained on [ImageNet](https://image-net.org/) as the base architecture. Fully connected layer in ResNet is replaced with two fully connected layers of size 2048. Dropout and ReLU are applied. We train all models with sigmoid cross-entropy loss for 20 epochs with a batch size of 32. We use the [Adam](https://arxiv.org/abs/1412.6980) optimizer with a learning rate of 1e-3.
#
# We have trained the Attribute Classifier and saved the model with the best accuracy on the validation set. Now let us get these pre-trained classifier weights and evaluate model fairness.
#
# PS:
# If you want to train the Attribute Classifier from scratch, please refer to our GitHub page and follow the steps.

# %%
# download the pre-trained weights
# !wget https://nnabla.org/pretrained-models/nnabla-examples/responsible_ai/prejudice_remover_regularizer_images/best_baseline.h5
# !wget https://nnabla.org/pretrained-models/nnabla-examples/responsible_ai/prejudice_remover_regularizer_images/val_baseline.pkl

# %%
nn.clear_parameters()

attribute_classifier_model = clf.AttributeClassifier(model_load_path=r'./best_baseline.h5')
# split the dataset
split_celeba_dataset(r'./data/celeba/images', r'./data/celeba/list_attr_celeba.txt', r'./test',split="test")
# load dataloader
test = data_iterator_celeba(img_path= r'./test',
                            attr_path= r'./data/celeba/list_attr_celeba.txt',
                            target_attribute ='Attractive', protected_attribute = 'Male',
                            batch_size=32)
cal_thresh = pickle.load(open(r'./val_baseline.pkl', 'rb'))['cal_thresh']

# %% [markdown]
# ### Model Fairness for Classifier

# %% [markdown]
# Let's start our investigation of classifier model fairness by analyzing the predictions made on the test set. In this tutorial, we use the Average Precision (AP) metric to measure classifier accuracy & three metrics to measure model fairness: Calders-Verwer score (CV score), Difference in Equality of Opportunity (DEO) and Bias Amplification (BA). CV Score is the absolute difference between conditional probabilities of the positive class for protected attributes. [DEO](https://arxiv.org/abs/2004.01355) is the absolute difference in False Negative Rate (FNR) for the protected attribute group. [BA](https://arxiv.org/abs/2102.12594) is a metric proposed by Wang and Russakovsky. Intuitively, BA measures how much more often a target attribute is predicted with a protected attribute than the ground truth value.

# %%
test_targets, test_scores = attribute_classifier_model.get_scores(test)
test_pred = np.where(test_scores > cal_thresh, 1, 0)
outf = test_scores[test_targets[:, 1] == 0]
outm = test_scores[test_targets[:, 1] == 1]
ap = utils.get_average_precision(test_targets[:, 0], test_scores)
cv_score = utils.get_cvs(outf,outm,cal_thresh)
deo = utils.get_diff_in_equal_opportunity(test_targets[:, 1],
                                              test_targets[:, 0], test_pred)
ba = utils.get_bias_amplification(test_targets[:, 1],
                                     test_targets[:, 0], test_pred)

# plot the fairness
utils.plot_fairness_multi(deo,cv_score,ba,ap,"Baseline")
print('Test results: ')
print('AP : {:.1f}', 100 * ap)
print('DEO : {:.1f}', 100 * deo)
print('BA : {:.1f}', 100 * ba)
print('CV : {:.1f}', 100 * cv_score)

# %% [markdown]
# As seen above, predictions are definitely not fair when considered in the context of `sex` as a sensitive attribute.
#
# Now let's mitigate the bias using `Prejudice Remover Regularizer'

# %% [markdown]
# ### 4. Prejudice Remover Regularizer
#
# Before going to the Prejudice Remover Regularizer method, let's understand what is prejudice and different prejudice methods.
#
# **Prejudice:** Prejudice means a statistical dependence between a sensitive variable S, and the target variable, Y, or a non-sensitive variable, X. There are three types of prejudices: `direct prejudice`, `indirect prejudice`, and `latent prejudice`
#
# 1. Direct prejudice: The prediction model directly depends on S
# 2. Indirect prejudice: Statistical dependence of Y on S, even lack of direct S
# 3. Latent prejudice: Statistical dependence of X on S
#
# In this tutorial we discuss how to reduce Indirect prejudice, using the Prejudice Removal Regularization Technique. We next show an index to quantify the degree of indirect prejudice, which is defined as the mutual information between Y and S.
# $$PI =\sum_{y,s∈D}\hat{Pr}[y,s] ln\frac{\hat{Pr}[y, s]}{\hat{Pr}[y]\hat{Pr}[s]}$$, we refer this index as a `prejudice index`(PI for short).

# %% [markdown]
# In this PRR technique, there are two types of regularizers. PRR technique involves adding two regularizer terms to cost function: L2 regularizer, $||θ||^2$, to reduce over-fitting and Prejudice remover regularizer, $R(D,θ)$, to enforce fair classification. So, the objective function to minimize is rewritten as :

# %%
img = cv2.imread('images/Prejudice_Remover_Regularizer_Equation.png')
cv2_imshow(img)

# %% [markdown]
# where λ and η are positive regularization parameters.
#
# in the above equation prejudice remover regularizer:
# * Directly tries to reduce the prejudice index(PI).
# * Smaller value more strongly constraints independence b/w Y and S
#
# in short :
#
# PRLR : Loss function(log-likelihood) + Prejudice Remover Regularizer(mutual information) + l2 Regularizer

# %% [markdown]
# We have trained the PRR model and saved the model with the best accuracy on the validation set. If you want to train the PRR model from the scratch please refer to our GitHub page and follow the steps.
#
# Now let us get the pre-trained weights for the PRR and load the model. The supplied λ and η values, that tune fairness versus accuracy, are set to λ = 1e-05 and η = 2 (If η is 0, the network behaves as a simple base class classifier network). We heuristically found that these settings result in a balanced increase of the fairness value during training. You may train with different regularization parameter values and check the impact of different λ and η values on model performance and fairness.
#
# Let's check the model fairness after PRR training

# %%
# !wget https://nnabla.org/pretrained-models/nnabla-examples/responsible_ai/prejudice_remover_regularizer_images/best_prr.h5
# !wget https://nnabla.org/pretrained-models/nnabla-examples/responsible_ai/prejudice_remover_regularizer_images/val_prr.pkl

# %%
nn.clear_parameters()

attribute_classifier_model = clf.AttributeClassifier(model_load_path=r'./best_prr.h5')
# split the dataset
# split_celeba_dataset(r'./data/celeba/images', r'./data/celeba/list_attr_celeba.txt', r'./test',split="test")
# load dataloader
test = data_iterator_celeba(img_path= r'./test',
                            attr_path= r'./data/celeba/list_attr_celeba.txt',
                            target_attribute ='Attractive', protected_attribute = 'Male',
                            batch_size=32)
cal_thresh = pickle.load(open(r'./val_prr.pkl', 'rb'))['cal_thresh']

# %% [markdown]
# ### Model Fairness: with PRR

# %%
test_targets, test_scores = attribute_classifier_model.get_scores(test)
test_pred = np.where(test_scores > cal_thresh, 1, 0)
outf = test_scores[test_targets[:, 1] == 0]
outm = test_scores[test_targets[:, 1] == 1]
ap = utils.get_average_precision(test_targets[:, 0], test_scores)

cv_score = utils.get_cvs(outf,outm,cal_thresh)

deo = utils.get_diff_in_equal_opportunity(test_targets[:, 1],
                                                     test_targets[:, 0], test_pred)
ba = utils.get_bias_amplification(test_targets[:, 1],
                                     test_targets[:, 0], test_pred)

utils.plot_fairness_multi(deo,cv_score,ba,ap,"PRR")
print('Test results: ')
print('AP : {:.1f}', 100 * ap)
print('DEO : {:.1f}', 100 * deo)
print('BA : {:.1f}', 100 * ba)
print('CV : {:.1f}', 100 * cv_score)

# %% [markdown]
# Plots above show how model fairness improved after induction of PRR into training. DEO & CV score have improved compared to the baseline model. After PRR training, classification accuracy has dropped. But, it can be controlled. Ideally, user must take a call on acceptable amount of trade off between accuracy and fairness.

# %% [markdown]
# ### 5. Summary
#
# In this tutorial, we have demonstrated how to reduce indirect prejudice using `Prejudice Remover Regularizer` procedure in a visual recognition task.
# Also, note that it is not possible to optimize a model for all the fairness metrics in real-time: to read more about this, explore the [Impossibility Theorem of Machine Fairness](https://arxiv.org/abs/2007.06024).
#
# Also, making fair predictions comes at a cost: sometimes it will reduce the performance [AP] of our model (hopefully, only little). However, in many cases, this would be a small price to pay.

# %% [markdown]
# ### 6. References

# %% [markdown]
# 1. "Fairness-aware classifier with prejudice remover regularizer". Toshihiro Kamishima, Shotaro Akaho, Hideki Asoh & Jun Sakuma. Joint European Conference on Machine Learning and Knowledge Discovery in Databases ECML PKDD 2012: Machine Learning and Knowledge Discovery in Databases pp 35–50.
# 2. "Equality of opportunity in supervised learning". Hardt, Moritz, Eric Price, and Nati Srebro.Advances in neural information processing systems 29 (2016)
# 3. "Directional bias amplification". Wang, Angelina, and Olga Russakovsky. International Conference on Machine Learning. PMLR, 2021.
# 4. "The Impossibility Theorem of Machine Fairness--A Causal Perspective".Saravanakumar, Kailash Karthik. arXiv preprint arXiv:2007.06024 (2020).
# 5. "Adam: A method for stochastic optimization". Kingma, Diederik P., and Jimmy Ba. arXiv preprint arXiv:1412.6980 (2014).
# 6. "Large-scale celebfaces attributes (celeba) dataset". Liu, Ziwei, Ping Luo, Xiaogang Wang, and Xiaoou Tang.  Retrieved August 15, no. 2018 (2018): 11.
